# %%
import requests

# %%
response = requests.post(url='https://ramannagari06.app.n8n.cloud/webhook-test/1bead7fa-0157-4d2c-9677-926852a4b018',json={'name':'hi how are you'})

# %%
response.status_code
# Out:
# 200

# %%
response.json()[0]['output']
# Out:
# "I'm doing well, thank you for asking!\n\nHow about you?"
